# %%
from PretrainedModels.imagenet import get_pre_trained_model, ModelOptions

# %%
model, trans = get_pre_trained_model(ModelOptions.ALEXNET)
# Out:
# /storage/vaibhav/a3/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /storage/vaibhav/a3/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
from PIL import Image
from torchvision import transforms

image = Image.open("./imagenette2/train/n02102040/ILSVRC2012_val_00000665.JPEG")

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x334>

# %%
image = trans(image)

# %%
image
# Out:
# tensor([[[0.1059, 0.1098, 0.1137,  ..., 0.4706, 0.4745, 0.4118],
#          [0.1216, 0.1216, 0.1255,  ..., 0.4745, 0.4902, 0.4392],
#          [0.1373, 0.1373, 0.1373,  ..., 0.4314, 0.4824, 0.4980],
#          ...,
#          [0.3725, 0.3843, 0.3961,  ..., 0.6118, 0.6118, 0.6235],
#          [0.3882, 0.3961, 0.4039,  ..., 0.6392, 0.6235, 0.6118],
#          [0.3882, 0.3961, 0.4078,  ..., 0.6392, 0.6078, 0.5882]],
#
#         [[0.1961, 0.2039, 0.2078,  ..., 0.3725, 0.3843, 0.3294],
#          [0.2157, 0.2235, 0.2235,  ..., 0.3765, 0.4039, 0.3608],
#          [0.2314, 0.2353, 0.2431,  ..., 0.3333, 0.3882, 0.4000],
#          ...,
#          [0.4549, 0.4667, 0.4941,  ..., 0.6902, 0.6902, 0.6980],
#          [0.4863, 0.4902, 0.5137,  ..., 0.7176, 0.6941, 0.6824],
#          [0.4863, 0.4980, 0.5176,  ..., 0.7059, 0.6706, 0.6588]],
#
#         [[0.3529, 0.3569, 0.3608,  ..., 0.3922, 0.3961, 0.3412],
#          [0.3725, 0.3843, 0.3882,  ..., 0.3765, 0.4078, 0.3765],
# ...

# %%
import torch
batch=torch.unsqueeze(image,0)

# %%
pred=model(batch)

# %%
pred.shape
# Out:
# torch.Size([1, 1000])

# %%
pred= torch.argmax(pred,1)

# %%
pred[0]
# Out:
# tensor(217)
